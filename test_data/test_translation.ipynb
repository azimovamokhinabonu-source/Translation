# %%
import json

file_path="al_manifest_100.jsonl"
data=[]

with open(file_path, "r", encoding="utf-8") as my_file:
    for line in my_file:
        data.append(json.loads(line))

print("Umumiy yozuvlar soni:", len(data))

for o in range(10):
    print(f"{o}: {data[o]['text']}")
# Out:
# Umumiy yozuvlar soni: 100
# 0: Bugun ertalab Gyotenikiga taklifnoma oldim.
# 1: Uning badiiy tasvir imkoniyatlarini rivojlantiradi
# 2: Udan koʻra balandroq joy bor.
# 3: Bu jumlada figʻoni falakka chiqib birikmasi ibora boʻlgani uchun vergul talab qilmaydi.
# 4: Bundan tashqari puxta jamlangan kutubxona bor.
# 5: Ularni hal qilishni paysalga soladi.
# 6: Xullas, qiziq maqola, oʻqishni tavsiya qilaman.
# 7: Diningizni kimdan olayotganingizga qarang.
# 8: Ota-onasi kitob oʻqigan bolalardir.
# 9: Shu tariqa qandaydir ezgu ishni amalga oshirasiz

# %%
print(data[0])
print(data[0].keys())
text=data[0]["text"]
print(text)
# Out:
# {'audio_filepath': '/workspace/clean/uz/common_voice_uz/audio/common_voice_uz_00000000.wav', 'duration': 4.788, 'text': 'Bugun ertalab Gyotenikiga taklifnoma oldim.'}
# dict_keys(['audio_filepath', 'duration', 'text'])
# Bugun ertalab Gyotenikiga taklifnoma oldim.

# %%
import torch

print("torch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name())
# Out:
# torch: 2.8.0a0+5228986c39.nv25.06
# CUDA: True
# GPU: NVIDIA B200

# %%
import transformers
print(transformers.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import transformers
#       2 print(transformers.__version__)
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import sys
print(sys.executable)

# %pip show transfomers
# Out:
# /usr/bin/python
# WARNING: Package(s) not found: transfomers
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/madlad400-10b-mt")
model = AutoModelForSeq2SeqLM.from_pretrained("google/madlad400-10b-mt", device_map="auto")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
#       3 tokenizer = AutoTokenizer.from_pretrained("google/madlad400-10b-mt")
#       4 model = AutoModelForSeq2SeqLM.from_pretrained("google/madlad400-10b-mt", device_map="auto")
#
# ModuleNotFoundError: No module named 'transformers'
